# %% [markdown]
# # Introduction to Data Visualization in Python

# %% [markdown]
# ## Why is Data Visualization Important?
#
# Data visualization is a key skill in data analysis, data science, and communication. Here's why it matters:
#
# ### 🧠 1. Helps You Understand Data Better
# Raw data in spreadsheets or tables can be hard to interpret. Visualization transforms rows and columns of numbers into **visual meaning**, making it easier to:
#
# - Spot **trends** and **patterns**
# - Identify **outliers** and **anomalies**
# - Understand the **distribution** of values
#
# > Example: A sales report across months might just look like numbers, but a line chart can instantly show upward or downward trends.
#
# ---
#
# ### 📢 2. Communicates Insights Clearly
#
# Visuals make it easier to share findings with both **technical and non-technical stakeholders**. Instead of describing relationships in words, a good graph shows the story in seconds.
#
# > Think of dashboards in business — they condense complex performance metrics into charts that anyone can understand at a glance.
#
# ---
#
# ### ⌛ 3. Saves Time in Decision Making
#
# Data visualization **reduces time spent on analysis** and **speeds up decisions** by:
#
# - Highlighting key issues immediately
# - Allowing interactive filtering and zooming (in tools like Plotly or Bokeh)
# - Making it easier to compare multiple variables or categories simultaneously
#
# ---
#
# ### ❌ What Happens If We Don't Visualize Data?
#
# Without visualization:
#
# - You may **miss important insights** buried in raw data
# - Errors and outliers may go **undetected**
# - Stakeholders may **misinterpret** findings due to poor communication
# - You spend **more time exploring** instead of concluding
#
# ---
#
# ### 🔍 Bottom Line
#
# > **"A picture is worth a thousand rows."**
#
# Data visualization turns complex datasets into visual narratives, improving **comprehension**, **communication**, and **decision-making speed**.

# %% [markdown]
# ## Types of Visualizations
#
# There are various types of visualizations, each useful for different purposes:
#
# - **Line Plot** – Trends over time
# - **Bar Plot** – Comparing categories
# - **Histogram** – Distribution of a variable
# - **Box Plot** – Summary statistics with outliers
# - **Scatter Plot** – Relationship between two numerical variables
# - **Heatmap** – Correlation and matrix plots
# - **Interactive Plots** – Tools like Bokeh and Plotly for dynamic exploration

# %% [markdown]
# ## Python Libraries for Data Visualization
#
# Several powerful libraries exist in Python for creating both static and interactive visualizations:
#
# - **Matplotlib**: The foundation of most Python plotting libraries.
# - **Seaborn**: Built on top of Matplotlib, simplifies statistical plotting.
# - **Bokeh**: Enables interactive plots for web applications.
# - **Plotly**: Offers elegant, interactive plots ideal for dashboards and web use.
#
# We'll cover each of these libraries with hands-on examples.

# %% [markdown]
# ## What You Will Learn
#
# By the end of this tutorial, you will be able to:
#
# - Understand the role of visualization in data science.
# - Create various types of plots using:
#   - Matplotlib
#   - Seaborn
#   - Bokeh
#   - Plotly
# - Compare static and interactive plotting techniques.
# - Use these libraries to explore and communicate data insights.

# %% [markdown]
# ## 📘 Introduction to Matplotlib
#
# **Matplotlib** is one of the most widely used data visualization libraries in Python. It provides powerful tools for creating static, animated, and interactive plots.
#
# - Developed by John Hunter in 2003
# - Inspired by MATLAB-style plotting
# - Works well with NumPy and Pandas
#
# Matplotlib is the foundation of many other libraries such as **Seaborn**, which builds on its functionality for statistical plotting.

# %% [markdown]
# ## 🧭 Why Use Matplotlib?
#
# Matplotlib is:
#
# - ✅ **Versatile** – Can create line plots, bar charts, scatter plots, histograms, and more
# - 🎨 **Customizable** – You can control every aspect of a plot (colors, fonts, grids, axes)
# - 🧱 **Foundational** – Many other libraries (like Seaborn and Pandas’ built-in plotting) are built on it
#
# ### 💼 Where is it used?
#
# - Exploratory Data Analysis (EDA)
# - Academic & scientific publications
# - Dashboard visuals (static ones)
# - Reports and presentations
#
# > Matplotlib is your go-to tool when you need **full control** over your visual output.

# %% [markdown]
# ## 🔧 Common Plotting Functions in Matplotlib
#
# Here are some commonly used functions:
#
# | Function | Description |
# |---------|-------------|
# | `plot()` | Line plots |
# | `scatter()` | Scatter plots (X-Y) |
# | `bar()` / `barh()` | Bar charts (vertical/horizontal) |
# | `hist()` | Histogram |
# | `boxplot()` | Box and whisker plot |
# | `pie()` | Pie chart |
# | `imshow()` | Show image data |
# | `subplot()` | Create multiple plots in a single figure |

# %% [markdown]
# ## 💾 Installing and Importing Matplotlib
#
# Before using Matplotlib, you need to install it (if not already installed).
#
# ### ✅ Installation using pip
#
# Open your terminal or notebook cell and run:
#
# ```bash
# pip install matplotlib

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 📈 Line Plot
#
# ### ✅ When to Use:
# - To show **trends over time**
# - To track changes or progression
# - Often used in time series analysis
#
# > Example: Stock prices, temperature change, sales over months

# %%
# 🧪 Example: Temperature Over a Week

days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
temps = [21, 23, 19, 24, 22, 27, 26]

plt.plot(days, temps, marker='^', linestyle='-', color='teal')
plt.title('Temperature Over a Week')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()

# %%
# Change line to solid and color to red
plt.plot(days, temps, marker='o', linestyle='-', color='red')
plt.title('Test 1: Solid Red Line with Square Markers')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()




# # Use triangle markers and remove grid
# plt.plot(days, temps, marker='^', linestyle='--', color='green')
# plt.title('Test 2: Green Dashed Line with Triangles')
# plt.xlabel('Day')
# plt.ylabel('Temperature (°C)')
# plt.grid(False)
# plt.show()




# # Add two temperature lines (e.g., this week vs last week)
last_week = [20, 22, 18, 23, 21, 25, 24]

plt.plot(days, temps, marker='o', linestyle='--', label='This Week', color='blue')
plt.plot(days, last_week, marker='s', linestyle='-', label='Last Week', color='orange')
plt.title('Test 3: Temperature Comparison')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.show()



# # Reverse the temperature list
# plt.plot(days, temps[::-1], marker='D', linestyle='-', color='purple')
# plt.title('Test 4: Reversed Temperature Data')
# plt.xlabel('Day')
# plt.ylabel('Temperature (°C)')
# plt.grid(True)
# plt.show()



# # Custom figure size and font sizes
# plt.figure(figsize=(10, 5))
# plt.plot(days, temps, marker='o', linestyle='--', color='teal')
# plt.title('Test 5: Custom Figure Size', fontsize=16)
# plt.xlabel('Day', fontsize=12)
# plt.ylabel('Temperature (°C)', fontsize=12)
# plt.grid(True)
# plt.show()

# %%
# # Reverse the temperature list
plt.plot(days, temps[::-1], marker='D', linestyle='-', color='purple')
plt.title('Test 4: Reversed Temperature Data')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()



# # Custom figure size and font sizes
plt.figure(figsize=(10, 5))
plt.plot(days, temps, marker='o', linestyle='--', color='teal')
plt.title('Test 5: Custom Figure Size', fontsize=16)
plt.xlabel('Day', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📊 Bar Chart
#
# ### ✅ When to Use:
# - To **compare categories**
# - Good for **frequency counts**, survey responses, or group comparisons
#
# > Example: Number of students per class, sales per region, product ratings

# %%
# 🧪 Example: Clinic Visits Per Day
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
visits = [20, 30, 30, 25, 10, 5, 15]

plt.bar(days, visits, color='orange')
plt.title('Clinic Visits Per Day')
plt.xlabel('Day')
plt.ylabel('Number of Visits')
plt.show()

# %%
# # Change bar color to blue and adjust bar width
plt.bar(days, visits, color='blue', width=0.5)
plt.title('Test 1: Blue Bars with Narrow Width')
plt.xlabel('Day')
plt.ylabel('Number of Visits')
plt.show()




# Flip the bars horizontally
plt.barh(days, visits, color='green')
plt.title('Test 2: Horizontal Bar Chart')
plt.xlabel('Number of Visits')
plt.ylabel('Day')
plt.show()



# Add numeric labels above each bar
bars = plt.bar(days, visits, color='orange')
plt.title('Test 3: Clinic Visits with Labels')
plt.xlabel('Day')
plt.ylabel('Number of Visits')

# Add value labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval , yval, ha='center', va='bottom')

plt.show()




# # Widen the figure and rotate x-axis labels
# plt.figure(figsize=(10, 5))
# plt.bar(days, visits, color='purple')
# plt.title('Test 4: Rotated Labels with Custom Size')
# plt.xlabel('Day')
# plt.ylabel('Number of Visits')
# plt.xticks(rotation=45)
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.show()




# Compare current week vs previous week
import numpy as np

previous_week = [15, 30, 28, 20, 12, 10, 18]
x = np.arange(len(days))

plt.bar(x - 0.2, visits, width=0.4, label='This Week', color='teal')
plt.bar(x + 0.2, previous_week, width=0.4, label='Last Week', color='coral')
plt.xticks(x, days)
plt.title('Test 5: Weekly Comparison of Visits')
plt.xlabel('Day')
plt.ylabel('Number of Visits')
plt.legend()
plt.show()

# %% [markdown]
# ## 🔴 Scatter Plot
#
# ### ✅ When to Use:
# - To show the **relationship or correlation** between two numerical variables
# - Useful in regression, clustering, and outlier detection
#
# > Example: Study hours vs exam scores, advertising budget vs sales

# %%
# 🧪 Example: Study Hours vs Exam Score
study_hours = [1, 2, 3, 4, 5, 6, 7]
exam_scores = [50, 55, 60, 63, 70, 75, 80]

plt.scatter(study_hours, exam_scores, color='green')
plt.title('Study Hours vs Exam Score')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
# # Use different marker shape and color
# plt.scatter(study_hours, exam_scores, color='purple', marker='^')
# plt.title('Test 1: Triangle Markers (Purple)')
# plt.xlabel('Hours Studied')
# plt.ylabel('Score')
# plt.grid(True)
# plt.show()




# Bubble size varies with hours studied (just for demo)
sizes = [s * 20 for s in study_hours]

plt.scatter(study_hours, exam_scores, color='teal', s=sizes)
plt.title('Test 2: Bubble Size Based on Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.grid(True)
plt.show()






# plt.scatter(study_hours, exam_scores, color='orange')

# # Add labels for each point
# for i in range(len(study_hours)):
#     plt.text(study_hours[i] + 0.1, exam_scores[i], f"{exam_scores[i]}")

# plt.title('Test 3: Annotated Points')
# plt.xlabel('Hours Studied')
# plt.ylabel('Score')
# plt.grid(True)
# plt.show()



colors = ['green' if score >= 60 else 'red' for score in exam_scores]

plt.scatter(study_hours, exam_scores, color=colors)
plt.title('Test 5: Color by Pass/Fail (Green ≥ 60)')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.scatter(study_hours, exam_scores, color='orange')

# # Add labels for each point
for i in range(len(study_hours)):
    plt.text(study_hours[i] + 0.1, exam_scores[i], f"{exam_scores[i]}")

plt.title('Test 3: Annotated Points')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📊 Histogram
#
# ### ✅ When to Use:
# - To show the **distribution** of a single numeric variable
# - Helps identify **frequency**, **skewness**, **normality**, or **outliers**
#
# > Example: Age distribution, test score frequency, income distribution

# %%
# 🧪 Example: Age Distribution of Survey Respondents
ages = [22, 25, 26, 22, 30, 28, 24, 32, 35, 28, 24, 27, 40, 42, 30]

plt.hist(ages, bins=2, color='purple', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.show()

# %%
# Test 2: More bins (finer granularity)
plt.hist(ages, bins=10, color='teal', edgecolor='black')
plt.title('More Bins (10)')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Test 2: More bins (finer granularity)
# plt.hist(ages, bins=10, color='teal', edgecolor='black')
# plt.title('More Bins (10)')
# plt.xlabel('Age')
# plt.ylabel('Count')

# # Test 3: Horizontal histogram

plt.hist(ages, bins=5, color='orange', edgecolor='black', orientation='horizontal')
plt.title('Horizontal')
plt.xlabel('Count')
plt.ylabel('Age')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📦 Box Plot
#
# ### ✅ When to Use:
# - To visualize **summary statistics** like median, quartiles, and outliers
# - Great for comparing **distributions** across multiple groups
#
# > Example: Compare salaries of different departments, marks of students across sections

# %%
# 🧪 Example: Test Scores of Two Classes
class_A = [55, 60, 65, 70, 75, 80, 85]
class_B = [58, 62, 67, 73, 78, 85, 88]

plt.boxplot([class_A, class_B], tick_labels=['Class A', 'Class B'])
plt.title('Score Distribution by Class')
plt.ylabel('Marks')
plt.grid(True)
plt.show()

# %%
# Test 2: More bins (finer granularity)
plt.hist(ages, bins=10, color='teal', edgecolor='black')
plt.title('More Bins (10)')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# 🔹 Test 3: Horizontal Boxplot
plt.boxplot([class_A, class_B], labels=['Class A', 'Class B'], vert=False)
plt.title('Test 3: Horizontal Boxplot')
plt.xlabel('Marks')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_16539/4212634943.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([class_A, class_B], labels=['Class A', 'Class B'], vert=False)

# %%
# 🔹 Test 4: Styled Boxplot with Colors
plt.boxplot([class_A, class_B],
             labels=['Class A', 'Class B'],
             patch_artist=True,
             boxprops=dict(facecolor='lightblue'),
             medianprops=dict(color='red', linewidth=2),
             showmeans=True,
             meanprops=dict(marker='o', markerfacecolor='black', markersize=6))
plt.title('Test 4: Styled Boxplot with Mean')
plt.ylabel('Marks')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_16539/359381900.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([class_A, class_B],

# %%
# 🔹 Test 2: Show Mean on Boxplot
# plt.boxplot([class_A, class_B], labels=['Class A', 'Class B'], showmeans=True)
# plt.title('Test 2: Boxplot with Mean')
# plt.ylabel('Marks')
# plt.grid(True)
# plt.show()

# 🔹 Test 3: Horizontal Boxplot
# plt.boxplot([class_A, class_B], labels=['Class A', 'Class B'], vert=False)
# plt.title('Test 3: Horizontal Boxplot')
# plt.xlabel('Marks')
# plt.grid(True)
# plt.show()

# 🔹 Test 4: Styled Boxplot with Colors
# plt.boxplot([class_A, class_B],
#             labels=['Class A', 'Class B'],
#             patch_artist=True,
#             boxprops=dict(facecolor='lightblue'),
#             medianprops=dict(color='red', linewidth=2),
#             showmeans=True,
#             meanprops=dict(marker='o', markerfacecolor='black', markersize=6))
# plt.title('Test 4: Styled Boxplot with Mean')
# plt.ylabel('Marks')
# plt.grid(True)
# plt.show()

# 🔹 Test 5: Unequal Data Lengths
class_C = [60, 65, 70]
plt.boxplot([class_A, class_B, class_C], labels=['Class A', 'Class B', 'Class C'])
plt.title('Test 5: Boxplot with Unequal Lengths')
plt.ylabel('Marks')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_16539/772916118.py:30: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([class_A, class_B, class_C], labels=['Class A', 'Class B', 'Class C'])

# %% [markdown]
# ## 🥧 Pie Chart
#
# ### ✅ When to Use:
# - To show **proportions or percentages** of a whole
# - Works well when you have **limited categories** and want to highlight dominance
#
# > Example: Market share, budget breakdown, survey response percentages

# %%
# 🧪 Example: Favorite Fruit Distribution
labels = ['Apple', 'Banana', 'Orange', 'Mango']
sizes = [30, 25, 20, 25]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['red', 'yellow', 'orange', 'green'])
plt.title('Favorite Fruits Survey')
plt.show()

# %% [markdown]
# ## 📐 What are Subplots and Layouts?
#
# ### ✅ What is a Subplot?
#
# A **subplot** is a way to show multiple plots (charts) in a single figure window.
#
# - Think of it as creating a **grid of plots** — like a collage of charts.
# - This helps compare multiple variables or visualizations side-by-side.
#
# ### 🧱 Layout
#
# The layout refers to how the subplots are **arranged in rows and columns**.
#
# ### 🔧 Common Function:
# ```python
# plt.subplot(n_rows, n_columns, index)
#
# - n_rows: total number of rows
# - n_columns: total number of columns
# - index: plot position (starting from 1)
#
# Another more flexible way (recommended for modern code) is:

# %% [markdown]
# fig, axes = plt.subplots(n_rows, n_columns)

# %%
### 🧪 Cell: Example – Using `plt.subplot()`

# Example: Displaying a line plot and bar chart side by side
import matplotlib.pyplot as plt

days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
temps = [21, 23, 19, 24, 22]
visits = [20, 35, 30, 25, 10]

plt.figure(figsize=(10, 4))

# Line Plot
plt.subplot(1, 2, 1)
plt.plot(days, temps, marker='o')
plt.title('Temperature')

# Bar Chart
plt.subplot(1, 2, 2)
plt.bar(days, visits, color='orange')
plt.title('Clinic Visits')

plt.tight_layout()
plt.show()

# %%
# Example: Using subplots() for better control
fig, axes = plt.subplots(2, 2, figsize=(10, 8))





# Line Plot
axes[0, 0].plot([1, 2, 3], [10, 20, 30])
axes[0, 0].set_title('Line Plot')

# Bar Chart
axes[0, 1].bar(['A', 'B', 'C'], [5, 7, 3])
axes[0, 1].set_title('Bar Chart')

# Histogram
axes[1, 0].hist([22, 25, 25, 30, 28, 28, 35], bins=3)
axes[1, 0].set_title('Histogram')

axes[1, 1].scatter([1, 2, 3], [4, 5, 6])
axes[1, 1].set_title('Scatter Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 💾 Saving Plots to Files
#
# After creating a plot with Matplotlib, you can save it as an image file using:
#
# ```python
# plt.savefig("filename.extension")
#
# - Supports formats like: .png, .jpg, .svg, .pdf, .eps
# - You must call savefig() before plt.show()
# - You can customize resolution using dpi (dots per inch)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y, marker='o')
plt.title('Sample Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Save before showing
plt.savefig('line_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ## 📘 Introduction to Seaborn
#
# **Seaborn** is a Python data visualization library built on top of **Matplotlib**. It provides a **high-level interface** for drawing attractive and informative statistical graphics.
#
# - Built on top of Matplotlib
# - Integrates well with Pandas DataFrames
# - Designed for statistical plots and data exploration
#
# Seaborn simplifies the process of creating complex plots and is ideal for **exploratory data analysis (EDA)**.
#
# ---
#
# ## 🧭 Why Use Seaborn?
#
# Seaborn is:
#
# - ✅ **Simpler Syntax** – Less code to produce complex plots
# - 🎨 **Aesthetically Pleasing** – Beautiful default color palettes and themes
# - 📊 **Statistical Insight** – Built-in support for distributions, regression, and category comparisons
#
# ### 💼 Where is it used?
#
# - Data science and machine learning pipelines
# - Exploratory analysis and correlation studies
# - Quick and attractive reports
#
# > Seaborn is your go-to when you want **beautiful statistical visuals quickly**.
#
# ---
#
# ## 🔧 Common Plotting Functions in Seaborn
#
# Here are some commonly used Seaborn functions:
#
# | Function         | Description                                 |
# |------------------|---------------------------------------------|
# | `barplot()`      | Bar plot with aggregation (mean by default) |
# | `lineplot()`     | Line plot with confidence intervals         |
# | `scatterplot()`  | Scatter plot with grouping (hue, style)     |
# | `boxplot()`      | Box-and-whisker plot                        |
# | `violinplot()`   | Combination of KDE + boxplot                |
# | `heatmap()`      | Colored matrix (correlation, etc.)          |
# | `pairplot()`     | Pairwise plots across columns               |
# | `distplot()` (deprecated) | Distribution plot (now use `displot`)   |

# %% [markdown]
# ## 💾 Installing and Importing Seaborn
#
# If you don’t have Seaborn installed, use:
#
# ```bash
# pip install seaborn

# %%
import seaborn as sns

# %%
# Load example dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 📊 Seaborn Bar Plot
#
# ### ✅ When to Use:
# - To compare **means** or **aggregated values** across categories
# - Automatically computes **confidence intervals**
#
# > Example: Average bill amount by gender

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
plt.title('Average Total Bill by Gender')
plt.show()

# %%
# 🔹 Test 3: Horizontal Bar Plot
sns.barplot(y='sex', x='total_bill', data=tips)
plt.title('Test 3: Horizontal Bar Plot')
plt.show()

# %%
sns.barplot(x='day', y='total_bill', data=tips, estimator=np.sum)
plt.title('Test 4: Total Bill by Day (Sum)')
plt.show()

# %%
# # 🔹 Test 5: Customize Color Palette
sns.barplot(x='day', y='tip', data=tips, hue='day', palette='Set2', legend=True)
plt.title('Test 5: Tip Amount by Day (Custom Colors)')
plt.show()

# %%
# 🔹 Test 2: Add Hue for Time (Lunch/Dinner comparison)
sns.barplot(x='sex', y='total_bill', hue='time', data=tips)
plt.title('Test 2: Average Total Bill by Gender & Time')
plt.show()

# 🔹 Test 3: Horizontal Bar Plot
# sns.barplot(y='sex', x='total_bill', data=tips)
# plt.title('Test 3: Horizontal Bar Plot')
# plt.show()

# 🔹 Test 4: Use Estimator = sum instead of mean
import numpy as np
# sns.barplot(x='day', y='total_bill', data=tips, estimator=np.sum)
# plt.title('Test 4: Total Bill by Day (Sum)')
# plt.show()

# # 🔹 Test 5: Customize Color Palette
# sns.barplot(x='day', y='tip', data=tips, hue='day', palette='Set2', legend=True)
# plt.title('Test 5: Tip Amount by Day (Custom Colors)')
# plt.show()

# %% [markdown]
# ## 📈 Seaborn Line Plot
#
# ### ✅ When to Use:
# - To show **trends over time** or a continuous variable
# - Automatically computes **confidence interval** shading
#
# > Example: Trend of tips by size of group

# %%
sns.lineplot(x='size', y='tip', data=tips)
plt.title('Tip vs Group Size')
plt.show()

# %%
# 🔹 Test 2: Add Hue (line per time: Lunch/Dinner)
sns.lineplot(x='size', y='tip', data=tips, hue='time')
plt.title('Test 2: Tip vs Group Size by Time')
plt.show()

# 🔹 Test 3: Use Median instead of Mean
# sns.lineplot(x='size', y='tip', data=tips, estimator=np.median)
# plt.title('Test 3: Median Tip vs Group Size')
# plt.show()

# 🔹 Test 4: Show Confidence Interval (default: 95%)
# sns.lineplot(x='size', y='tip', data=tips, ci=95)
# plt.title('Test 4: Tip vs Group Size with CI=95%')
# plt.show()

# %%
# 🔹 Test 3: Use Median instead of Mean
sns.lineplot(x='size', y='tip', data=tips, estimator=np.median)
plt.title('Test 3: Median Tip vs Group Size')
plt.show()

# %%
# 🔹 Test 4: Show Confidence Interval (default: 95%)
sns.lineplot(x='size', y='tip', data=tips, ci=95)
plt.title('Test 4: Tip vs Group Size with CI=95%')
plt.show()
# Out:
# /tmp/ipykernel_16539/3481789441.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.lineplot(x='size', y='tip', data=tips, ci=95)

# %% [markdown]
# ## 🔴 Seaborn Scatter Plot
#
# ### ✅ When to Use:
# - To show relationships between two numeric variables
# - Use `hue` to add a categorical third dimension
#
# > Example: Total bill vs tip amount, color-coded by gender

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
plt.title('Tip vs Total Bill')
plt.show()

# %%
# 🔹 Test 2: Add Style to Differentiate Points
sns.scatterplot(x='total_bill', y='tip', hue='sex', style='time', data=tips)
plt.title('Test 2: Tip vs Total Bill (Color by Gender, Shape by Time)')
plt.show()

# 🔹 Test 3: Change Size of Points by Group Size
# sns.scatterplot(x='total_bill', y='tip', size='size', hue='sex', data=tips)
# plt.title('Test 3: Tip vs Total Bill (Point Size = Group Size)')
# plt.show()

# 🔹 Test 4: Customize Palette and Markers
# sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips, palette='Set1', marker='D')
# plt.title('Test 4: Custom Colors and Markers')
# plt.show()

# 🔹 Test 5: Add Regression Line with Scatterplot
# sns.regplot(x='total_bill', y='tip', data=tips, scatter=True)
# plt.title('Test 5: Tip vs Total Bill with Regression Line')
# plt.show()

# %%
# 🔹 Test 3: Change Size of Points by Group Size
sns.scatterplot(x='total_bill', y='tip', size='size', hue='sex', data=tips)
plt.title('Test 3: Tip vs Total Bill (Point Size = Group Size)')
plt.show()

# %%
# 🔹 Test 4: Customize Palette and Markers
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips, palette='Set1', marker='D')
plt.title('Test 4: Custom Colors and Markers')
plt.show()

# %%
# 🔹 Test 5: Add Regression Line with Scatterplot
sns.regplot(x='total_bill', y='tip', data=tips, scatter=True)
plt.title('Test 5: Tip vs Total Bill with Regression Line')
plt.show()

# %% [markdown]
# ## 📦 Seaborn Box Plot
#
# ### ✅ When to Use:
# - To compare distributions and identify outliers across categories
#
# > Example: Distribution of total bills by day of the week

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Total Bill Distribution by Day')
plt.show()

# %% [markdown]
# ## 🌀 Seaborn Violin Plot
#
# ### ✅ When to Use:
# - To visualize **distribution + summary statistics** in one chart
#
# > Combines boxplot + KDE (kernel density estimation)

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin Plot of Bills by Day')
plt.show()

# %% [markdown]
# ## 🔥 Seaborn Heatmap
#
# ### ✅ When to Use:
# - To visualize **correlations** or any matrix-form data
#
# > Example: Correlation between numerical features in the tips dataset

# %%
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## 📘 Introduction to Bokeh
#
# **Bokeh** is an interactive visualization library that targets **modern web browsers** for presentation.
#
# - Supports interactive, zoomable, and filterable plots
# - Generates standalone HTML files or notebook displays
# - Good for dashboards and web apps
#
# Bokeh allows for more **dashboard-like**, **responsive**, and **web-native visualizations** than Matplotlib or Seaborn.
#
# ---
#
# ## 🧭 Why Use Bokeh?
#
# Bokeh is:
#
# - ✅ **Interactive** – Hover tools, zoom, pan, and clickable legends
# - 🌐 **Web-Friendly** – Plots are rendered in the browser
# - 🧰 **Flexible Layouts** – Combine multiple plots with widgets
#
# ### 💼 Where is it used?
#
# - Web dashboards and data apps
# - Real-time data streaming
# - Interactive exploratory tools
#
# > Bokeh is perfect when you want **interactive control over data visualizations**.
#
# ---
#
# ## 🔧 Common Plotting Functions in Bokeh
#
# | Function            | Description                             |
# |---------------------|-----------------------------------------|
# | `figure()`          | Creates a blank canvas for plotting     |
# | `.line()`           | Draws line plots                        |
# | `.circle()`         | Scatter plots using circular markers     |
# | `.vbar()` / `.hbar()`| Vertical/horizontal bar charts          |
# | `.rect()`           | Used for creating heatmaps              |
# | `output_notebook()` | Displays plot inside Jupyter Notebook   |
# | `output_file()`     | Saves interactive plot to HTML file     |
# | `show()`            | Displays the plot                       |

# %% [markdown]
# ## 💾 Installing and Importing Bokeh
#
# Install Bokeh using pip:
#
# ```bash
# pip install bokeh

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()  # Use this inside Jupyter notebooks

# %% [markdown]
# ---
#
# ### 🧪 Cell 3: Basic Line Plot
# ```markdown
# ## 📈 Bokeh Example: Line Plot
#
# ### ✅ When to Use:
# - To show trends and changes over time with interactivity
# - Hover and zoom for detailed exploration

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()

# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Create a figure
p = figure(title="Basic Line Plot", x_axis_label='X', y_axis_label='Y')

# Add a line renderer
p.line(x, y, line_width=2)

# Show the plot
show(p)
# Out:
#   <div id="b79dbbd1-82bc-4f11-902c-df2e0899ed54" data-root-id="p1054" style="display: contents;"></div>

# %% [markdown]
# ## 🟣 Bokeh Example: Bar Chart
#
# ### ✅ When to Use:
# - To compare categories interactively (hover, zoom, click)
#
# > Example: Sales per product category

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource

output_notebook()

fruits = ['Apple', 'Banana', 'Orange']
counts = [10, 20, 15]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, height=300, title="Fruit Sales")
p.vbar(x='fruits', top='counts', width=0.6, source=source, color="orange")

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
#   <div id="f41eeda4-60f0-4316-92f5-9628a75a8365" data-root-id="p1103" style="display: contents;"></div>

# %% [markdown]
# ## 🔴 Bokeh Example: Interactive Scatter Plot
#
# ### ✅ When to Use:
# - To explore relationships between variables with hover tooltips
#
# > Example: Income vs Age

# %%
from bokeh.models import HoverTool

# Sample data
x = [20, 25, 30, 35, 40, 45]
y = [20000, 25000, 27000, 30000, 32000, 35000]

p = figure(title="Age vs Income", x_axis_label='Age', y_axis_label='Income')

p.circle(x, y, size=10, color="navy", alpha=0.6)

hover = HoverTool(tooltips=[("Age", "@x"), ("Income", "@y")])
p.add_tools(hover)

show(p)
# Out:
# ...
#   <div id="d2e488f8-a7df-49e6-a776-33eba3500180" data-root-id="p1150" style="display: contents;"></div>

# %% [markdown]
# ## 📘 Introduction to Plotly
#
# **Plotly** is a high-level graphing library for building **interactive, web-based visualizations** with minimal effort.
#
# - Built on D3.js and WebGL
# - Works well in Jupyter, standalone HTML, and dashboards
# - Excellent for both quick visualizations and full dashboards
#
# Plotly is one of the most **modern** and **visually appealing** Python charting libraries.
#
# ---
#
# ## 🧭 Why Use Plotly?
#
# Plotly is:
#
# - ✅ **Highly Interactive** – Zoom, pan, hover, select, and animate
# - 🌍 **Web-Ready** – Export to HTML or integrate into web apps
# - 📦 **Versatile** – Supports 2D, 3D, geographic, and animated plots
#
# ### 💼 Where is it used?
#
# - Interactive dashboards (e.g., via Dash)
# - Web applications and analytics tools
# - Data exploration for stakeholders
#
# > Plotly is perfect when you need **presentation-ready visuals** with minimal effort.
#
# ---
#
# ## 🔧 Common Plotting Functions in Plotly
#
# | Function                     | Description                                |
# |------------------------------|--------------------------------------------|
# | `px.line()`                  | Line plot                                  |
# | `px.bar()`                   | Bar chart                                  |
# | `px.scatter()`               | Scatter plot with grouping and sizing      |
# | `px.box()`                   | Box-and-whisker plot                       |
# | `px.pie()`                   | Pie chart                                  |
# | `px.histogram()`             | Histogram                                  |
# | `px.choropleth()`            | Geographic heatmaps                        |
# | `px.imshow()`                | Image/matrix visualization                 |
# | `go.Figure()`                | Low-level, fully customizable Plotly plot  |

# %% [markdown]
# ## 💾 Installing and Importing Plotly
#
# Install Plotly using pip:
#
# ```bash
# pip install plotly

# %%
import plotly.express as px

# %% [markdown]
# You can also use plotly.graph_objects for more control, but plotly.express is great for most use cases.

# %% [markdown]
# ## 📈 Plotly Line Plot
#
# ### ✅ When to Use:
# - To show **trends over time** with zooming and hover interaction
#
# > Example: Stock prices or weather changes

# %%
import plotly.express as px

# Sample data
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
temp = [22, 25, 24, 23, 26]

fig = px.line(x=days, y=temp, title='Temperature Over the Week',
              labels={'x': 'Day', 'y': 'Temperature (°C)'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 🔹 Test 2: Add Markers to Line
fig = px.line(x=days, y=temp, title='Test 2: Line Plot with Markers',
              labels={'x': 'Day', 'y': 'Temperature (°C)'})
fig.update_traces(mode='lines+markers', marker=dict(size=10, color='red'))
fig.show()

# 🔹 Test 3: Custom Line Style
# fig = px.line(x=days, y=temp, title='Test 3: Custom Line Style',
#               labels={'x': 'Day', 'y': 'Temp (°C)'})
# fig.update_traces(line=dict(dash='dashdot', width=3, color='green'))
# fig.show()

# 🔹 Test 4: Show Hover Labels Always
# fig = px.line(x=days, y=temp, title='Test 4: Always Show Hover Labels',
#               labels={'x': 'Day', 'y': 'Temperature'})
# fig.update_traces(mode='lines+markers', hoverinfo='x+y', hoverlabel=dict(bgcolor="white"))
# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 🔹 Test 3: Custom Line Style
fig = px.line(x=days, y=temp, title='Test 3: Custom Line Style',
               labels={'x': 'Day', 'y': 'Temp (°C)'})
fig.update_traces(line=dict(dash='dashdot', width=3, color='green'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 🔹 Test 4: Show Hover Labels Always
fig = px.line(x=days, y=temp, title='Test 4: Always Show Hover Labels',
               labels={'x': 'Day', 'y': 'Temperature'})
fig.update_traces(mode='lines+markers', hoverinfo='x+y', hoverlabel=dict(bgcolor="white"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📊 Plotly Bar Chart
#
# ### ✅ When to Use:
# - To compare values across categories, with hover details
#
# > Example: Number of students per department

# %%
departments = ['CS', 'Math', 'Physics', 'Bio']
students = [120, 80, 60, 40]

fig = px.bar(x=departments, y=students, title='Students Per Department',
             labels={'x': 'Department', 'y': 'Number of Students'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 🔹 Test 2: Custom Color
# fig = px.bar(x=departments, y=students, title='Test 2: Custom Color',
#              labels={'x': 'Department', 'y': 'Students'},
#              color=students, color_continuous_scale='viridis')
# fig.show()

# 🔹 Test 3: Horizontal Bars
# fig = px.bar(x=students, y=departments, orientation='h',
#              title='Test 3: Horizontal Bar Chart',
#              labels={'x': 'Number of Students', 'y': 'Department'})
# fig.show()

# 🔹 Test 4: Add Text Labels on Bars
fig = px.bar(x=departments, y=students, text=students,
             title='Test 4: Students per Department with Labels',
             labels={'x': 'Department', 'y': 'Number of Students'})
fig.update_traces(textposition='inside')
fig.show()

# 🔹 Test 5: Sorted Bar Chart
sorted_depts = sorted(zip(students, departments), reverse=True)
sorted_students, sorted_departments = zip(*sorted_depts)
fig = px.bar(x=sorted_departments, y=sorted_students,
             title='Test 5: Sorted Bar Chart',
             labels={'x': 'Department', 'y': 'Students'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 🔹 Test 2: Custom Color
fig = px.bar(x=departments, y=students, title='Test 2: Custom Color',
              labels={'x': 'Department', 'y': 'Students'},
              color=students, color_continuous_scale='viridis')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 🔴 Plotly Scatter Plot
#
# ### ✅ When to Use:
# - To show relationships with **color**, **size**, or **hover info**
#
# > Example: Income vs Age, with gender or region coloring

# %%
import pandas as pd

# Create sample DataFrame
df = pd.DataFrame({
    'Age': [25, 30, 35, 40, 45],
    'Income': [30_000, 40_000, 50_000, 60_000, 70_000],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female']
})

fig = px.scatter(df, x='Age', y='Income', color='Gender', size='Income',
                 title='Income vs Age by Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📦 Plotly Box Plot
#
# ### ✅ When to Use:
# - To compare distributions and spot outliers interactively
#
# > Example: Compare salaries or scores across different groups

# %%
df = px.data.tips()  # Built-in dataset

fig = px.box(df, x='day', y='total_bill', color='sex',
             title='Total Bill Distribution by Day and Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 🌡️ Plotly Heatmap
#
# ### ✅ When to Use:
# - To visualize 2D matrices or correlation between variables
#
# > Example: Correlation matrix, activity levels

# %%
import numpy as np
import plotly.figure_factory as ff

# Create a 2D array
z = np.random.rand(5, 5)
x = ['A', 'B', 'C', 'D', 'E']
y = ['W', 'X', 'Y', 'Z', 'Q']

fig = ff.create_annotated_heatmap(z, x=x, y=y, colorscale='Viridis')
fig.update_layout(title='Simulated Heatmap')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📍 Plotly Map Plot (Optional)
#
# ### ✅ When to Use:
# - For geographic data visualizations (choropleths, scatter geo)
#
# > Example: Display number of users by country

# %%
df = px.data.gapminder().query("year == 2007")

fig = px.choropleth(df, locations="iso_alpha", color="lifeExp",
                    hover_name="country", projection="natural earth",
                    title='Life Expectancy by Country (2007)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📚 Summary: Comparing Visualization Libraries
#
# Here's a quick comparison of the four major Python visualization libraries we've covered:
#
# | Library     | Type        | Strengths                                                                 | Best Use Cases                             |
# |-------------|-------------|---------------------------------------------------------------------------|--------------------------------------------|
# | **Matplotlib** | Static       | Full control, low-level API, highly customizable                        | Publications, detailed plots, subplots     |
# | **Seaborn**    | Static       | Built on Matplotlib, beautiful defaults, easy for statistical plots     | Quick EDA, distributions, correlations      |
# | **Bokeh**      | Interactive  | Web-ready plots, interactivity (hover, zoom, filters), good layout tools| Dashboards, web apps, data exploration      |
# | **Plotly**     | Interactive  | Very interactive, attractive UI, works with Dash, 3D and map support    | Dashboards, storytelling, 3D visualizations |
#
# ### 🔍 Key Takeaways
#
# - Use **Matplotlib** when you need precision, customization, and multi-plot control.
# - Use **Seaborn** for quick and beautiful statistical visualizations with fewer lines of code.
# - Use **Bokeh** if you want browser-based **interactivity** and layout control.
# - Use **Plotly** for modern, interactive dashboards or when working with 3D or map-based data.
#
# > 🔧 Choose the right tool based on your audience (technical vs. non-technical), need for interactivity, and the complexity of your data.
#
# Happy Visualizing! 🎨📊🧠
